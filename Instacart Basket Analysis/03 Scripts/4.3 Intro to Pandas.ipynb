# %% [markdown]
# # 4.3 Importing Libraries

# %% [markdown]
# # 4.3.3

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 4.3.5

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']
path = r'/Users/shailioza/Documents/CareerFoundry Projects/Instacart Basket Analysis/02 Data'

# %%
df = pd.read_csv(os.path.join(path, 'Original Data', 'orders.csv'), usecols = vars_list)

# %% [markdown]
# # 4.3.6

# %%
df.shape
# Out:
# (3421083, 6)

# %%
df.head(5)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# # 4.3.7

# %%
df_prods = pd.read_csv(os.path.join(path, 'Original Data', 'products.csv'), index_col = False)

# %% [markdown]
# # 4.3.8

# %%
df_prods.head(20)
# Out:
#     Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0              0           0   2539329        1             1
# 1              1           1   2398795        1             2
# 2              2           2    473747        1             3
# 3              3           3   2254736        1             4
# 4              4           4    431534        1             5
# 5              5           5   3367565        1             6
# 6              6           6    550135        1             7
# 7              7           7   3108588        1             8
# 8              8           8   2295261        1             9
# 9              9           9   2550362        1            10
# 10            10          10   1187899        1            11
# 11            11          11   2168274        2             1
# 12            12          12   1501582        2             2
# 13            13          13   1901567        2             3
# ...

# %%
df_prods.tail(35)
# Out:
#          Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 3421048       3421048     3421048    726186   206208            30
# 3421049       3421049     3421049   2523609   206208            31
# 3421050       3421050     3421050    756221   206208            32
# 3421051       3421051     3421051   2254244   206208            33
# 3421052       3421052     3421052   2017995   206208            34
# 3421053       3421053     3421053   2789700   206208            35
# 3421054       3421054     3421054    844592   206208            36
# 3421055       3421055     3421055   1541132   206208            37
# 3421056       3421056     3421056   2808240   206208            38
# 3421057       3421057     3421057   3027766   206208            39
# 3421058       3421058     3421058   3356245   206208            40
# 3421059       3421059     3421059    442304   206208            41
# 3421060       3421060     3421060   2675140   206208            42
# ...

# %% [markdown]
# # 4.3.9

# %%
df_prods.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'order_id', 'user_id', 'order_number',
#        'orders_day_of_week', 'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %% [markdown]
# # 4.3.10

# %%
df_prods.shape
# Out:
# (3421083, 8)

# %%
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 8 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0.1            int64
#  1   Unnamed: 0              int64
#  2   order_id                int64
#  3   user_id                 int64
#  4   order_number            int64
#  5   orders_day_of_week      int64
#  6   order_hour_of_day       int64
#  7   days_since_prior_order  float64
# dtypes: float64(1), int64(7)
# memory usage: 208.8 MB

# %% [markdown]
# # 4.3.11

# %%
df_prods.describe()
# Out:
#        Unnamed: 0.1    Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# ...

# %% [markdown]
# As we see in the table above, the maximum value of the column,'aisle_id' is 134.00

# %%
df_prods.dtypes
# Out:
# Unnamed: 0.1                int64
# Unnamed: 0                  int64
# order_id                    int64
# user_id                     int64
# order_number                int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
df_prods.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0

# %% [markdown]
# The data type of the column,'department_id' is integer
