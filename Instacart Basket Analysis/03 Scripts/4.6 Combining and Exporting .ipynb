# %% [markdown]
# # Import libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import dataframes

# %%
#Importing data set orders_wrangled.csv
df_ords = pd.read_csv(r'/Users/shailioza/Documents/CareerFoundry Projects/Instacart Basket Analysis/02 Data/Prepared Data/orders_wrangled.csv', index_col = False)

# %%
#Importing data set orders products prior.csv
df_ords_prior = pd.read_csv(r'/Users/shailioza/Documents/CareerFoundry Projects/Instacart Basket Analysis/02 Data/Prepared Data/order_products__prior.csv', index_col = False)

# %% [markdown]
# # Check and merge dataframe

# %%
#Check imported data set
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#Check imported data set
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
#Check dataframe size
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
#Check dataframe size
df_ords.shape
# Out:
# (3421083, 7)

# %%
#Merge df_ords and df_ords_prior
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
#Check merged dataframe
df_merged_large.head(30)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            0   2539329        1             1                   2
# 2            0   2539329        1             1                   2
# 3            0   2539329        1             1                   2
# 4            0   2539329        1             1                   2
# 5            1   2398795        1             2                   3
# 6            1   2398795        1             2                   3
# 7            1   2398795        1             2                   3
# 8            1   2398795        1             2                   3
# 9            1   2398795        1             2                   3
# 10           1   2398795        1             2                   3
# 11           2    473747        1             3                   3
# 12           2    473747        1             3                   3
# ...

# %%
# Check value counts for '_merge' column
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # Export merged data

# %%
# Export df_merged_large as .pkl
df_merged_large.to_pickle('/Users/shailioza/Documents/CareerFoundry Projects/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl')
