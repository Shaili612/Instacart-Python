# %% [markdown]
# # Import libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import dataframe

# %%
#Importing data set orders_products_merged.pkl
ords_prods_merge = pd.read_pickle('/Users/shailioza/Documents/CareerFoundry Projects/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged_2.pkl')

# %%
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          0         Soda        77              7     9.0   both
# 1          1         Soda        77              7     9.0   both
# 2          1         Soda        77              7     9.0   both
# 3          1         Soda        77              7     9.0   both
# 4          1         Soda        77              7     9.0   both
#
#       busiest_day    busiest_days busiest_period_of_day    price_range_loc
# 0  Regularly busy  Regularly days        Average orders  Mid-range product
# 1  Regularly busy    Slowest days        Average orders  Mid-range product
# 2  Regularly busy    Slowest days           Most orders  Mid-range product
# 3      Least busy    Slowest days        Average orders  Mid-range product
# 4      Least busy    Slowest days           Most orders  Mid-range product

# %% [markdown]
# # Grouping data with pandas

# %%
# To recap, you should always use the groupby() function as part of a series of steps, namely, the following:

# 1. Split the data into groups based on some criteria.
# 2. Apply a function to each group separately.
# 3. Combine the results into a dataframe or alternative data structure or create a new column in the current dataframe.

# So far, you’ve only completed the first step—splitting the data into groups (with the group being the “product_name” column)

# %%
df.groupby('product_name')

# %% [markdown]
# # Aggregate data with agg()

# %%
#  If you were to calculate the mean of the “order_number” column grouped by the “department_id” column,
# you could quickly compare the average number of orders across each Instacart department.
# This will involve two of the steps in the three-step process introduced above:

# 1. Split the data into groups based on “department_id.”
# 2. Apply the agg() function to each group to obtain the mean values for the “order_number” column.

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # Aggregate data with transform()

# %%
# Now, let’s map this task onto the three-step process introduced earlier:

# 1. Split the data into groups based on the “user_id” column.
# 2. Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# 3. Create a new column, “max_order,” into which you’ll place the results of your aggregation.

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# df_orders_products_merged['max_order'] = df_orders_products_merged.groupby(['user_id'])['order_number'].transform(np.max)

# Let’s run through each piece of the code in turn:
# First, a new column called “max_order” is created, which will be what stores the maximum order number for each user (step 3).
# Then, the df_orders_products_merged dataframe is grouped by the “user_id” column (step 1).
# And finally, the transform() function is applied on the “order_number” column with the np.max argument (step 2).

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            1   2398795        1             2                   3
# 2            2    473747        1             3                   3
# 3            3   2254736        1             4                   4
# 4            4    431534        1             5                   4
# ..         ...       ...      ...           ...                 ...
# 95        5895   3226575      360             1                   5
# 96        6137   1469869      377             3                   5
# 97        6259   1927023      387             2                   4
# 98        6740    858092      420             4                   1
# 99        6741    119314      420             5                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# ..                ...                     ...         ...                ...
# 95                 12                     NaN         196                  1
# 96                 17                     3.0         196                  9
# 97                 10                    22.0         196                  3
# 98                 19                    30.0         196                  2
# 99                 19                    16.0         196                  2
#
#     reordered product_name  aisle_id  department_id  prices _merge  \
# 0           0         Soda        77              7     9.0   both
# 1           1         Soda        77              7     9.0   both
# 2           1         Soda        77              7     9.0   both
# 3           1         Soda        77              7     9.0   both
# 4           1         Soda        77              7     9.0   both
# ..        ...          ...       ...            ...     ...    ...
# 95          0         Soda        77              7     9.0   both
# 96          0         Soda        77              7     9.0   both
# 97          0         Soda        77              7     9.0   both
# 98          0         Soda        77              7     9.0   both
# 99          1         Soda        77              7     9.0   both
#
#        busiest_day    busiest_days busiest_period_of_day    price_range_loc  \
# 0   Regularly busy  Regularly days        Average orders  Mid-range product
# 1   Regularly busy    Slowest days        Average orders  Mid-range product
# 2   Regularly busy    Slowest days           Most orders  Mid-range product
# 3       Least busy    Slowest days        Average orders  Mid-range product
# 4       Least busy    Slowest days           Most orders  Mid-range product
# ..             ...             ...                   ...                ...
# 95  Regularly busy  Regularly days           Most orders  Mid-range product
# 96  Regularly busy  Regularly days        Average orders  Mid-range product
# 97      Least busy    Slowest days           Most orders  Mid-range product
# 98  Regularly busy    Busiest days        Average orders  Mid-range product
# 99  Regularly busy    Slowest days        Average orders  Mid-range product
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# ..        ...
# 95          3
# 96          3
# 97          8
# 98         22
# 99         22
#
# [100 rows x 20 columns]

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            1   2398795        1             2                   3
# 2            2    473747        1             3                   3
# 3            3   2254736        1             4                   4
# 4            4    431534        1             5                   4
# 5            5   3367565        1             6                   2
# 6            6    550135        1             7                   1
# 7            7   3108588        1             8                   1
# 8            8   2295261        1             9                   1
# 9            9   2550362        1            10                   4
# 10         144   2968173       15            15                   1
# 11         146   1870022       15            17                   2
# 12         147   1911383       15            18                   2
# 13         150   2715276       15            21                   1
# 14         151    487368       15            22                   1
# 15         209   2293453       19             2                   5
# 16         212   1973799       19             5                   6
# 17         214    532817       19             7                   4
# 18         232   1573906       21            10                   3
# 19         458   1593000       31            10                   3
# 20         465   2231262       31            17                   3
# 21         617   2580647       43             6                   4
# 22         620   2187180       43             9                   4
# 23         751   2497897       52             1                   1
# 24         752   1318871       52             2                   1
# 25         753   1261384       52             3                   1
# 26         755    580568       52             5                   2
# 27         757   2428073       52             7                   2
# 28         759    342306       52             9                   1
# 29         760   1520353       52            10                   2
# 30         761   2542086       52            11                   2
# 31         762    944694       52            12                   1
# 32         765   1268191       52            15                   2
# 33         767   1122089       52            17                   2
# 34         768   1498922       52            18                   2
# 35         769    180919       52            19                   3
# 36         771   2695875       52            21                   5
# 37        1022   3205960       67             1                   3
# 38        1023    970922       67             2                   1
# 39        1024    596585       67             3                   1
# 40        1025   2037087       67             4                   2
# 41        1026   2474111       67             5                   3
# 42        1027   1568481       67             6                   3
# 43        1029   2048527       67             8                   2
# 44        1030   2389031       67             9                   2
# 45        1031   2378562       67            10                   1
# 46        1032   1515698       67            11                   1
# 47        1033   1928050       67            12                   2
# 48        1034   1949274       67            13                   1
# 49        1035    551869       67            14                   1
# 50        1037    768572       67            16                   4
# 51        1039    150528       67            18                   5
# 52        1040     29758       67            19                   0
# 53        1042   1558976       67            21                   1
# 54        1043    863974       67            22                   1
# 55        1044   2308399       67            23                   1
# 56        1202   2759128       81             3                   1
# 57        1204   1812985       81             5                   2
# 58        1208   1889835       82             1                   3
# 59        1210    499460       82             3                   5
# 60        1211   2728456       82             4                   0
# 61        1213   2653743       82             6                   4
# 62        1216   1358880       82             9                   1
# 63        1217    343588       82            10                   2
# 64        1222   3034663       82            15                   2
# 65        1225    147262       82            18                   1
# 66        1226   3144004       82            19                   2
# 67        1480   2126069       98             3                   0
# 68        1484   2210120       98             7                   5
# 69        1486    681011       98             9                   3
# 70        1488   2846344       98            11                   4
# 71        1489    747431       98            12                   6
# 72        1490   2383054       98            13                   4
# 73        1491   1993729       98            14                   5
# 74        1608   1403849      109             3                   3
# 75        1744    520620      120             1                   3
# 76        1746   3273029      120             3                   2
# 77        2781   1861943      185             2                   1
# 78        2891   2040988      195             1                   1
# 79        2898   1680569      195             8                   1
# 80        2909    276171      195            19                   5
# 81        2912   2744976      195            22                   5
# 82        2915   2781919      195            25                   1
# 83        2921   1738718      195            31                   2
# 84        2924   3058369      195            34                   3
# 85        2927   1485596      195            37                   2
# 86        2930    417035      195            40                   3
# 87        2937   1615297      195            47                   5
# 88        2942   1765587      195            52                   3
# 89        2947    745908      195            57                   4
# 90        3451   2505656      222            17                   2
# 91        3472   3268370      222            38                   5
# 92        4667   2016711      290             9                   5
# 93        4686   2706088      290            28                   6
# 94        5551   1952286      331             6                   5
# 95        5895   3226575      360             1                   5
# 96        6137   1469869      377             3                   5
# 97        6259   1927023      387             2                   4
# 98        6740    858092      420             4                   1
# 99        6741    119314      420             5                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
# 20                 11                     8.0         196                 14
# 21                 16                     4.0         196                  9
# 22                 12                     3.0         196                  1
# 23                  9                     NaN         196                  4
# 24                 10                     7.0         196                  5
# 25                 10                     7.0         196                  3
# 26                 10                     8.0         196                  6
# 27                  7                     8.0         196                  5
# 28                 11                     7.0         196                  5
# 29                 10                     8.0         196                  4
# 30                  9                     7.0         196                  3
# 31                 16                     6.0         196                  7
# 32                 11                     8.0         196                  3
# 33                 10                     6.0         196                  4
# 34                 10                    14.0         196                  6
# 35                  8                     8.0         196                  4
# 36                 10                    30.0         196                  1
# 37                 11                     NaN         196                  1
# 38                 15                     5.0         196                  2
# 39                 13                     7.0         196                  2
# 40                  9                     8.0         196                  1
# 41                 14                     8.0         196                  2
# 42                 12                     7.0         196                  2
# 43                 11                     7.0         196                  1
# 44                 14                     7.0         196                  1
# 45                 10                     6.0         196                  1
# 46                 11                     7.0         196                  1
# 47                 12                     8.0         196                  1
# 48                 10                     6.0         196                  1
# 49                  9                     7.0         196                  1
# 50                 10                     9.0         196                  1
# 51                 16                     4.0         196                  1
# 52                 14                     9.0         196                  2
# 53                  9                     5.0         196                  2
# 54                 11                    14.0         196                  3
# 55                 14                    14.0         196                  1
# 56                  9                    14.0         196                  2
# 57                 20                    30.0         196                  1
# 58                 15                     NaN         196                  6
# 59                 10                     5.0         196                  2
# 60                 11                    16.0         196                  1
# 61                  9                    13.0         196                  5
# 62                 10                    30.0         196                  1
# 63                 11                     1.0         196                  1
# 64                 11                    12.0         196                  1
# 65                 13                     7.0         196                  1
# 66                 15                     8.0         196                  1
# 67                  9                    25.0         196                  7
# 68                 14                     5.0         196                  1
# 69                  9                    30.0         196                  1
# 70                 13                    15.0         196                  2
# 71                 13                    30.0         196                  4
# 72                 11                    30.0         196                  1
# 73                  8                     8.0         196                  2
# 74                 17                     9.0         196                  5
# 75                 11                     NaN         196                  2
# 76                  8                    19.0         196                  2
# 77                 12                    25.0         196                 10
# 78                 14                     NaN         196                  2
# 79                  9                     4.0         196                  2
# 80                 11                     3.0         196                  2
# 81                 10                     7.0         196                  2
# 82                 14                     4.0         196                  1
# 83                  8                     4.0         196                  2
# 84                 10                     6.0         196                  2
# 85                 15                     0.0         196                  2
# 86                 16                     2.0         196                  2
# 87                 10                     2.0         196                  2
# 88                 12                     2.0         196                  3
# 89                 11                     3.0         196                  3
# 90                 12                     1.0         196                  2
# 91                 15                     1.0         196                  6
# 92                 19                     6.0         196                  8
# 93                 10                     7.0         196                 16
# 94                 16                    30.0         196                  8
# 95                 12                     NaN         196                  1
# 96                 17                     3.0         196                  9
# 97                 10                    22.0         196                  3
# 98                 19                    30.0         196                  2
# 99                 19                    16.0         196                  2
#
#     reordered product_name  aisle_id  department_id  prices _merge  \
# 0           0         Soda        77              7     9.0   both
# 1           1         Soda        77              7     9.0   both
# 2           1         Soda        77              7     9.0   both
# 3           1         Soda        77              7     9.0   both
# 4           1         Soda        77              7     9.0   both
# 5           1         Soda        77              7     9.0   both
# 6           1         Soda        77              7     9.0   both
# 7           1         Soda        77              7     9.0   both
# 8           1         Soda        77              7     9.0   both
# 9           1         Soda        77              7     9.0   both
# 10          0         Soda        77              7     9.0   both
# 11          1         Soda        77              7     9.0   both
# 12          1         Soda        77              7     9.0   both
# 13          1         Soda        77              7     9.0   both
# 14          1         Soda        77              7     9.0   both
# 15          0         Soda        77              7     9.0   both
# 16          1         Soda        77              7     9.0   both
# 17          1         Soda        77              7     9.0   both
# 18          0         Soda        77              7     9.0   both
# 19          0         Soda        77              7     9.0   both
# 20          1         Soda        77              7     9.0   both
# 21          0         Soda        77              7     9.0   both
# 22          1         Soda        77              7     9.0   both
# 23          0         Soda        77              7     9.0   both
# 24          1         Soda        77              7     9.0   both
# 25          1         Soda        77              7     9.0   both
# 26          1         Soda        77              7     9.0   both
# 27          1         Soda        77              7     9.0   both
# 28          1         Soda        77              7     9.0   both
# 29          1         Soda        77              7     9.0   both
# 30          1         Soda        77              7     9.0   both
# 31          1         Soda        77              7     9.0   both
# 32          1         Soda        77              7     9.0   both
# 33          1         Soda        77              7     9.0   both
# 34          1         Soda        77              7     9.0   both
# 35          1         Soda        77              7     9.0   both
# 36          1         Soda        77              7     9.0   both
# 37          0         Soda        77              7     9.0   both
# 38          1         Soda        77              7     9.0   both
# 39          1         Soda        77              7     9.0   both
# 40          1         Soda        77              7     9.0   both
# 41          1         Soda        77              7     9.0   both
# 42          1         Soda        77              7     9.0   both
# 43          1         Soda        77              7     9.0   both
# 44          1         Soda        77              7     9.0   both
# 45          1         Soda        77              7     9.0   both
# 46          1         Soda        77              7     9.0   both
# 47          1         Soda        77              7     9.0   both
# 48          1         Soda        77              7     9.0   both
# 49          1         Soda        77              7     9.0   both
# 50          1         Soda        77              7     9.0   both
# 51          1         Soda        77              7     9.0   both
# 52          1         Soda        77              7     9.0   both
# 53          1         Soda        77              7     9.0   both
# 54          1         Soda        77              7     9.0   both
# 55          1         Soda        77              7     9.0   both
# 56          0         Soda        77              7     9.0   both
# 57          1         Soda        77              7     9.0   both
# 58          0         Soda        77              7     9.0   both
# 59          1         Soda        77              7     9.0   both
# 60          1         Soda        77              7     9.0   both
# 61          1         Soda        77              7     9.0   both
# 62          1         Soda        77              7     9.0   both
# 63          1         Soda        77              7     9.0   both
# 64          1         Soda        77              7     9.0   both
# 65          1         Soda        77              7     9.0   both
# 66          1         Soda        77              7     9.0   both
# 67          0         Soda        77              7     9.0   both
# 68          1         Soda        77              7     9.0   both
# 69          1         Soda        77              7     9.0   both
# 70          1         Soda        77              7     9.0   both
# 71          1         Soda        77              7     9.0   both
# 72          1         Soda        77              7     9.0   both
# 73          1         Soda        77              7     9.0   both
# 74          0         Soda        77              7     9.0   both
# 75          0         Soda        77              7     9.0   both
# 76          1         Soda        77              7     9.0   both
# 77          0         Soda        77              7     9.0   both
# 78          0         Soda        77              7     9.0   both
# 79          1         Soda        77              7     9.0   both
# 80          1         Soda        77              7     9.0   both
# 81          1         Soda        77              7     9.0   both
# 82          1         Soda        77              7     9.0   both
# 83          1         Soda        77              7     9.0   both
# 84          1         Soda        77              7     9.0   both
# 85          1         Soda        77              7     9.0   both
# 86          1         Soda        77              7     9.0   both
# 87          1         Soda        77              7     9.0   both
# 88          1         Soda        77              7     9.0   both
# 89          1         Soda        77              7     9.0   both
# 90          0         Soda        77              7     9.0   both
# 91          1         Soda        77              7     9.0   both
# 92          0         Soda        77              7     9.0   both
# 93          1         Soda        77              7     9.0   both
# 94          0         Soda        77              7     9.0   both
# 95          0         Soda        77              7     9.0   both
# 96          0         Soda        77              7     9.0   both
# 97          0         Soda        77              7     9.0   both
# 98          0         Soda        77              7     9.0   both
# 99          1         Soda        77              7     9.0   both
#
#        busiest_day    busiest_days busiest_period_of_day    price_range_loc  \
# 0   Regularly busy  Regularly days        Average orders  Mid-range product
# 1   Regularly busy    Slowest days        Average orders  Mid-range product
# 2   Regularly busy    Slowest days           Most orders  Mid-range product
# 3       Least busy    Slowest days        Average orders  Mid-range product
# 4       Least busy    Slowest days           Most orders  Mid-range product
# 5   Regularly busy  Regularly days        Average orders  Mid-range product
# 6   Regularly busy    Busiest days           Most orders  Mid-range product
# 7   Regularly busy    Busiest days           Most orders  Mid-range product
# 8   Regularly busy    Busiest days           Most orders  Mid-range product
# 9       Least busy    Slowest days        Average orders  Mid-range product
# 10  Regularly busy    Busiest days           Most orders  Mid-range product
# 11  Regularly busy  Regularly days           Most orders  Mid-range product
# 12  Regularly busy  Regularly days           Most orders  Mid-range product
# 13  Regularly busy    Busiest days           Most orders  Mid-range product
# 14  Regularly busy    Busiest days           Most orders  Mid-range product
# 15  Regularly busy  Regularly days           Most orders  Mid-range product
# 16  Regularly busy  Regularly days           Most orders  Mid-range product
# 17      Least busy    Slowest days        Average orders  Mid-range product
# 18  Regularly busy    Slowest days           Most orders  Mid-range product
# 19  Regularly busy    Slowest days        Average orders  Mid-range product
# 20  Regularly busy    Slowest days           Most orders  Mid-range product
# 21      Least busy    Slowest days           Most orders  Mid-range product
# 22      Least busy    Slowest days           Most orders  Mid-range product
# 23  Regularly busy    Busiest days           Most orders  Mid-range product
# 24  Regularly busy    Busiest days           Most orders  Mid-range product
# 25  Regularly busy    Busiest days           Most orders  Mid-range product
# 26  Regularly busy  Regularly days           Most orders  Mid-range product
# 27  Regularly busy  Regularly days        Average orders  Mid-range product
# 28  Regularly busy    Busiest days           Most orders  Mid-range product
# 29  Regularly busy  Regularly days           Most orders  Mid-range product
# 30  Regularly busy  Regularly days           Most orders  Mid-range product
# 31  Regularly busy    Busiest days           Most orders  Mid-range product
# 32  Regularly busy  Regularly days           Most orders  Mid-range product
# 33  Regularly busy  Regularly days           Most orders  Mid-range product
# 34  Regularly busy  Regularly days           Most orders  Mid-range product
# 35  Regularly busy    Slowest days        Average orders  Mid-range product
# 36  Regularly busy  Regularly days           Most orders  Mid-range product
# 37  Regularly busy    Slowest days           Most orders  Mid-range product
# 38  Regularly busy    Busiest days           Most orders  Mid-range product
# 39  Regularly busy    Busiest days           Most orders  Mid-range product
# 40  Regularly busy  Regularly days           Most orders  Mid-range product
# 41  Regularly busy    Slowest days           Most orders  Mid-range product
# 42  Regularly busy    Slowest days           Most orders  Mid-range product
# 43  Regularly busy  Regularly days           Most orders  Mid-range product
# 44  Regularly busy  Regularly days           Most orders  Mid-range product
# 45  Regularly busy    Busiest days           Most orders  Mid-range product
# 46  Regularly busy    Busiest days           Most orders  Mid-range product
# 47  Regularly busy  Regularly days           Most orders  Mid-range product
# 48  Regularly busy    Busiest days           Most orders  Mid-range product
# 49  Regularly busy    Busiest days           Most orders  Mid-range product
# 50      Least busy    Slowest days           Most orders  Mid-range product
# 51  Regularly busy  Regularly days           Most orders  Mid-range product
# 52     Busiest day    Busiest days           Most orders  Mid-range product
# 53  Regularly busy    Busiest days           Most orders  Mid-range product
# 54  Regularly busy    Busiest days           Most orders  Mid-range product
# 55  Regularly busy    Busiest days           Most orders  Mid-range product
# 56  Regularly busy    Busiest days           Most orders  Mid-range product
# 57  Regularly busy  Regularly days        Average orders  Mid-range product
# 58  Regularly busy    Slowest days           Most orders  Mid-range product
# 59  Regularly busy  Regularly days           Most orders  Mid-range product
# 60     Busiest day    Busiest days           Most orders  Mid-range product
# 61      Least busy    Slowest days           Most orders  Mid-range product
# 62  Regularly busy    Busiest days           Most orders  Mid-range product
# 63  Regularly busy  Regularly days           Most orders  Mid-range product
# 64  Regularly busy  Regularly days           Most orders  Mid-range product
# 65  Regularly busy    Busiest days           Most orders  Mid-range product
# 66  Regularly busy  Regularly days           Most orders  Mid-range product
# 67     Busiest day    Busiest days           Most orders  Mid-range product
# 68  Regularly busy  Regularly days           Most orders  Mid-range product
# 69  Regularly busy    Slowest days           Most orders  Mid-range product
# 70      Least busy    Slowest days           Most orders  Mid-range product
# 71  Regularly busy  Regularly days           Most orders  Mid-range product
# 72      Least busy    Slowest days           Most orders  Mid-range product
# 73  Regularly busy  Regularly days        Average orders  Mid-range product
# 74  Regularly busy    Slowest days        Average orders  Mid-range product
# 75  Regularly busy    Slowest days           Most orders  Mid-range product
# 76  Regularly busy  Regularly days        Average orders  Mid-range product
# 77  Regularly busy    Busiest days           Most orders  Mid-range product
# 78  Regularly busy    Busiest days           Most orders  Mid-range product
# 79  Regularly busy    Busiest days           Most orders  Mid-range product
# 80  Regularly busy  Regularly days           Most orders  Mid-range product
# 81  Regularly busy  Regularly days           Most orders  Mid-range product
# 82  Regularly busy    Busiest days           Most orders  Mid-range product
# 83  Regularly busy  Regularly days        Average orders  Mid-range product
# 84  Regularly busy    Slowest days           Most orders  Mid-range product
# 85  Regularly busy  Regularly days           Most orders  Mid-range product
# 86  Regularly busy    Slowest days           Most orders  Mid-range product
# 87  Regularly busy  Regularly days           Most orders  Mid-range product
# 88  Regularly busy    Slowest days           Most orders  Mid-range product
# 89      Least busy    Slowest days           Most orders  Mid-range product
# 90  Regularly busy  Regularly days           Most orders  Mid-range product
# 91  Regularly busy  Regularly days           Most orders  Mid-range product
# 92  Regularly busy  Regularly days        Average orders  Mid-range product
# 93  Regularly busy  Regularly days           Most orders  Mid-range product
# 94  Regularly busy  Regularly days           Most orders  Mid-range product
# 95  Regularly busy  Regularly days           Most orders  Mid-range product
# 96  Regularly busy  Regularly days        Average orders  Mid-range product
# 97      Least busy    Slowest days           Most orders  Mid-range product
# 98  Regularly busy    Busiest days        Average orders  Mid-range product
# 99  Regularly busy    Slowest days        Average orders  Mid-range product
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         22
# 11         22
# 12         22
# 13         22
# 14         22
# 15          9
# 16          9
# 17          9
# 18         33
# 19         20
# 20         20
# 21         11
# 22         11
# 23         27
# 24         27
# 25         27
# 26         27
# 27         27
# 28         27
# 29         27
# 30         27
# 31         27
# 32         27
# 33         27
# 34         27
# 35         27
# 36         27
# 37         24
# 38         24
# 39         24
# 40         24
# 41         24
# 42         24
# 43         24
# 44         24
# 45         24
# 46         24
# 47         24
# 48         24
# 49         24
# 50         24
# 51         24
# 52         24
# 53         24
# 54         24
# 55         24
# 56          7
# 57          7
# 58         19
# 59         19
# 60         19
# 61         19
# 62         19
# 63         19
# 64         19
# 65         19
# 66         19
# 67         14
# 68         14
# 69         14
# 70         14
# 71         14
# 72         14
# 73         14
# 74          6
# 75          3
# 76          3
# 77          6
# 78         58
# 79         58
# 80         58
# 81         58
# 82         58
# 83         58
# 84         58
# 85         58
# 86         58
# 87         58
# 88         58
# 89         58
# 90         70
# 91         70
# 92         51
# 93         51
# 94          8
# 95          3
# 96          3
# 97          8
# 98         22
# 99         22

# %% [markdown]
# # Deriving Columns with loc()

# %%
# To create your flag, you’ll need some criteria. You can use the following:

# 1. If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
# 2. If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
# 3. If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# The first set of brackets is the same as the brackets used in df['column'] above,
# while the second set of brackets is indicating that what you’re indexing is a list of multiple columns (and lists are always included within brackets).
# This is why there are two sets of brackets.
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %%
# You learned already that to access a single column in a dataframe, you can index it like so: df['column']

# %% [markdown]
# # TASK 4.8

# %%
# Step 1: Done

# %%
# Step 2:
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# Step 3: The means differ as the previous aggregation is conducted on a subset; therefore, only part of the data is used which creates difference in means and fewer numbers of user ids

# %%
# Step 4:
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            1   2398795        1             2                   3
# 2            2    473747        1             3                   3
# 3            3   2254736        1             4                   4
# 4            4    431534        1             5                   4
# 5            5   3367565        1             6                   2
# 6            6    550135        1             7                   1
# 7            7   3108588        1             8                   1
# 8            8   2295261        1             9                   1
# 9            9   2550362        1            10                   4
# 10         144   2968173       15            15                   1
# 11         146   1870022       15            17                   2
# 12         147   1911383       15            18                   2
# 13         150   2715276       15            21                   1
# 14         151    487368       15            22                   1
# 15         209   2293453       19             2                   5
# 16         212   1973799       19             5                   6
# 17         214    532817       19             7                   4
# 18         232   1573906       21            10                   3
# 19         458   1593000       31            10                   3
# 20         465   2231262       31            17                   3
# 21         617   2580647       43             6                   4
# 22         620   2187180       43             9                   4
# 23         751   2497897       52             1                   1
# 24         752   1318871       52             2                   1
# 25         753   1261384       52             3                   1
# 26         755    580568       52             5                   2
# 27         757   2428073       52             7                   2
# 28         759    342306       52             9                   1
# 29         760   1520353       52            10                   2
# 30         761   2542086       52            11                   2
# 31         762    944694       52            12                   1
# 32         765   1268191       52            15                   2
# 33         767   1122089       52            17                   2
# 34         768   1498922       52            18                   2
# 35         769    180919       52            19                   3
# 36         771   2695875       52            21                   5
# 37        1022   3205960       67             1                   3
# 38        1023    970922       67             2                   1
# 39        1024    596585       67             3                   1
# 40        1025   2037087       67             4                   2
# 41        1026   2474111       67             5                   3
# 42        1027   1568481       67             6                   3
# 43        1029   2048527       67             8                   2
# 44        1030   2389031       67             9                   2
# 45        1031   2378562       67            10                   1
# 46        1032   1515698       67            11                   1
# 47        1033   1928050       67            12                   2
# 48        1034   1949274       67            13                   1
# 49        1035    551869       67            14                   1
# 50        1037    768572       67            16                   4
# 51        1039    150528       67            18                   5
# 52        1040     29758       67            19                   0
# 53        1042   1558976       67            21                   1
# 54        1043    863974       67            22                   1
# 55        1044   2308399       67            23                   1
# 56        1202   2759128       81             3                   1
# 57        1204   1812985       81             5                   2
# 58        1208   1889835       82             1                   3
# 59        1210    499460       82             3                   5
# 60        1211   2728456       82             4                   0
# 61        1213   2653743       82             6                   4
# 62        1216   1358880       82             9                   1
# 63        1217    343588       82            10                   2
# 64        1222   3034663       82            15                   2
# 65        1225    147262       82            18                   1
# 66        1226   3144004       82            19                   2
# 67        1480   2126069       98             3                   0
# 68        1484   2210120       98             7                   5
# 69        1486    681011       98             9                   3
# 70        1488   2846344       98            11                   4
# 71        1489    747431       98            12                   6
# 72        1490   2383054       98            13                   4
# 73        1491   1993729       98            14                   5
# 74        1608   1403849      109             3                   3
# 75        1744    520620      120             1                   3
# 76        1746   3273029      120             3                   2
# 77        2781   1861943      185             2                   1
# 78        2891   2040988      195             1                   1
# 79        2898   1680569      195             8                   1
# 80        2909    276171      195            19                   5
# 81        2912   2744976      195            22                   5
# 82        2915   2781919      195            25                   1
# 83        2921   1738718      195            31                   2
# 84        2924   3058369      195            34                   3
# 85        2927   1485596      195            37                   2
# 86        2930    417035      195            40                   3
# 87        2937   1615297      195            47                   5
# 88        2942   1765587      195            52                   3
# 89        2947    745908      195            57                   4
# 90        3451   2505656      222            17                   2
# 91        3472   3268370      222            38                   5
# 92        4667   2016711      290             9                   5
# 93        4686   2706088      290            28                   6
# 94        5551   1952286      331             6                   5
# 95        5895   3226575      360             1                   5
# 96        6137   1469869      377             3                   5
# 97        6259   1927023      387             2                   4
# 98        6740    858092      420             4                   1
# 99        6741    119314      420             5                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
# 20                 11                     8.0         196                 14
# 21                 16                     4.0         196                  9
# 22                 12                     3.0         196                  1
# 23                  9                     NaN         196                  4
# 24                 10                     7.0         196                  5
# 25                 10                     7.0         196                  3
# 26                 10                     8.0         196                  6
# 27                  7                     8.0         196                  5
# 28                 11                     7.0         196                  5
# 29                 10                     8.0         196                  4
# 30                  9                     7.0         196                  3
# 31                 16                     6.0         196                  7
# 32                 11                     8.0         196                  3
# 33                 10                     6.0         196                  4
# 34                 10                    14.0         196                  6
# 35                  8                     8.0         196                  4
# 36                 10                    30.0         196                  1
# 37                 11                     NaN         196                  1
# 38                 15                     5.0         196                  2
# 39                 13                     7.0         196                  2
# 40                  9                     8.0         196                  1
# 41                 14                     8.0         196                  2
# 42                 12                     7.0         196                  2
# 43                 11                     7.0         196                  1
# 44                 14                     7.0         196                  1
# 45                 10                     6.0         196                  1
# 46                 11                     7.0         196                  1
# 47                 12                     8.0         196                  1
# 48                 10                     6.0         196                  1
# 49                  9                     7.0         196                  1
# 50                 10                     9.0         196                  1
# 51                 16                     4.0         196                  1
# 52                 14                     9.0         196                  2
# 53                  9                     5.0         196                  2
# 54                 11                    14.0         196                  3
# 55                 14                    14.0         196                  1
# 56                  9                    14.0         196                  2
# 57                 20                    30.0         196                  1
# 58                 15                     NaN         196                  6
# 59                 10                     5.0         196                  2
# 60                 11                    16.0         196                  1
# 61                  9                    13.0         196                  5
# 62                 10                    30.0         196                  1
# 63                 11                     1.0         196                  1
# 64                 11                    12.0         196                  1
# 65                 13                     7.0         196                  1
# 66                 15                     8.0         196                  1
# 67                  9                    25.0         196                  7
# 68                 14                     5.0         196                  1
# 69                  9                    30.0         196                  1
# 70                 13                    15.0         196                  2
# 71                 13                    30.0         196                  4
# 72                 11                    30.0         196                  1
# 73                  8                     8.0         196                  2
# 74                 17                     9.0         196                  5
# 75                 11                     NaN         196                  2
# 76                  8                    19.0         196                  2
# 77                 12                    25.0         196                 10
# 78                 14                     NaN         196                  2
# 79                  9                     4.0         196                  2
# 80                 11                     3.0         196                  2
# 81                 10                     7.0         196                  2
# 82                 14                     4.0         196                  1
# 83                  8                     4.0         196                  2
# 84                 10                     6.0         196                  2
# 85                 15                     0.0         196                  2
# 86                 16                     2.0         196                  2
# 87                 10                     2.0         196                  2
# 88                 12                     2.0         196                  3
# 89                 11                     3.0         196                  3
# 90                 12                     1.0         196                  2
# 91                 15                     1.0         196                  6
# 92                 19                     6.0         196                  8
# 93                 10                     7.0         196                 16
# 94                 16                    30.0         196                  8
# 95                 12                     NaN         196                  1
# 96                 17                     3.0         196                  9
# 97                 10                    22.0         196                  3
# 98                 19                    30.0         196                  2
# 99                 19                    16.0         196                  2
#
#     reordered  ... aisle_id  department_id  prices  _merge     busiest_day  \
# 0           0  ...       77              7     9.0    both  Regularly busy
# 1           1  ...       77              7     9.0    both  Regularly busy
# 2           1  ...       77              7     9.0    both  Regularly busy
# 3           1  ...       77              7     9.0    both      Least busy
# 4           1  ...       77              7     9.0    both      Least busy
# 5           1  ...       77              7     9.0    both  Regularly busy
# 6           1  ...       77              7     9.0    both  Regularly busy
# 7           1  ...       77              7     9.0    both  Regularly busy
# 8           1  ...       77              7     9.0    both  Regularly busy
# 9           1  ...       77              7     9.0    both      Least busy
# 10          0  ...       77              7     9.0    both  Regularly busy
# 11          1  ...       77              7     9.0    both  Regularly busy
# 12          1  ...       77              7     9.0    both  Regularly busy
# 13          1  ...       77              7     9.0    both  Regularly busy
# 14          1  ...       77              7     9.0    both  Regularly busy
# 15          0  ...       77              7     9.0    both  Regularly busy
# 16          1  ...       77              7     9.0    both  Regularly busy
# 17          1  ...       77              7     9.0    both      Least busy
# 18          0  ...       77              7     9.0    both  Regularly busy
# 19          0  ...       77              7     9.0    both  Regularly busy
# 20          1  ...       77              7     9.0    both  Regularly busy
# 21          0  ...       77              7     9.0    both      Least busy
# 22          1  ...       77              7     9.0    both      Least busy
# 23          0  ...       77              7     9.0    both  Regularly busy
# 24          1  ...       77              7     9.0    both  Regularly busy
# 25          1  ...       77              7     9.0    both  Regularly busy
# 26          1  ...       77              7     9.0    both  Regularly busy
# 27          1  ...       77              7     9.0    both  Regularly busy
# 28          1  ...       77              7     9.0    both  Regularly busy
# 29          1  ...       77              7     9.0    both  Regularly busy
# 30          1  ...       77              7     9.0    both  Regularly busy
# 31          1  ...       77              7     9.0    both  Regularly busy
# 32          1  ...       77              7     9.0    both  Regularly busy
# 33          1  ...       77              7     9.0    both  Regularly busy
# 34          1  ...       77              7     9.0    both  Regularly busy
# 35          1  ...       77              7     9.0    both  Regularly busy
# 36          1  ...       77              7     9.0    both  Regularly busy
# 37          0  ...       77              7     9.0    both  Regularly busy
# 38          1  ...       77              7     9.0    both  Regularly busy
# 39          1  ...       77              7     9.0    both  Regularly busy
# 40          1  ...       77              7     9.0    both  Regularly busy
# 41          1  ...       77              7     9.0    both  Regularly busy
# 42          1  ...       77              7     9.0    both  Regularly busy
# 43          1  ...       77              7     9.0    both  Regularly busy
# 44          1  ...       77              7     9.0    both  Regularly busy
# 45          1  ...       77              7     9.0    both  Regularly busy
# 46          1  ...       77              7     9.0    both  Regularly busy
# 47          1  ...       77              7     9.0    both  Regularly busy
# 48          1  ...       77              7     9.0    both  Regularly busy
# 49          1  ...       77              7     9.0    both  Regularly busy
# 50          1  ...       77              7     9.0    both      Least busy
# 51          1  ...       77              7     9.0    both  Regularly busy
# 52          1  ...       77              7     9.0    both     Busiest day
# 53          1  ...       77              7     9.0    both  Regularly busy
# 54          1  ...       77              7     9.0    both  Regularly busy
# 55          1  ...       77              7     9.0    both  Regularly busy
# 56          0  ...       77              7     9.0    both  Regularly busy
# 57          1  ...       77              7     9.0    both  Regularly busy
# 58          0  ...       77              7     9.0    both  Regularly busy
# 59          1  ...       77              7     9.0    both  Regularly busy
# 60          1  ...       77              7     9.0    both     Busiest day
# 61          1  ...       77              7     9.0    both      Least busy
# 62          1  ...       77              7     9.0    both  Regularly busy
# 63          1  ...       77              7     9.0    both  Regularly busy
# 64          1  ...       77              7     9.0    both  Regularly busy
# 65          1  ...       77              7     9.0    both  Regularly busy
# 66          1  ...       77              7     9.0    both  Regularly busy
# 67          0  ...       77              7     9.0    both     Busiest day
# 68          1  ...       77              7     9.0    both  Regularly busy
# 69          1  ...       77              7     9.0    both  Regularly busy
# 70          1  ...       77              7     9.0    both      Least busy
# 71          1  ...       77              7     9.0    both  Regularly busy
# 72          1  ...       77              7     9.0    both      Least busy
# 73          1  ...       77              7     9.0    both  Regularly busy
# 74          0  ...       77              7     9.0    both  Regularly busy
# 75          0  ...       77              7     9.0    both  Regularly busy
# 76          1  ...       77              7     9.0    both  Regularly busy
# 77          0  ...       77              7     9.0    both  Regularly busy
# 78          0  ...       77              7     9.0    both  Regularly busy
# 79          1  ...       77              7     9.0    both  Regularly busy
# 80          1  ...       77              7     9.0    both  Regularly busy
# 81          1  ...       77              7     9.0    both  Regularly busy
# 82          1  ...       77              7     9.0    both  Regularly busy
# 83          1  ...       77              7     9.0    both  Regularly busy
# 84          1  ...       77              7     9.0    both  Regularly busy
# 85          1  ...       77              7     9.0    both  Regularly busy
# 86          1  ...       77              7     9.0    both  Regularly busy
# 87          1  ...       77              7     9.0    both  Regularly busy
# 88          1  ...       77              7     9.0    both  Regularly busy
# 89          1  ...       77              7     9.0    both      Least busy
# 90          0  ...       77              7     9.0    both  Regularly busy
# 91          1  ...       77              7     9.0    both  Regularly busy
# 92          0  ...       77              7     9.0    both  Regularly busy
# 93          1  ...       77              7     9.0    both  Regularly busy
# 94          0  ...       77              7     9.0    both  Regularly busy
# 95          0  ...       77              7     9.0    both  Regularly busy
# 96          0  ...       77              7     9.0    both  Regularly busy
# 97          0  ...       77              7     9.0    both      Least busy
# 98          0  ...       77              7     9.0    both  Regularly busy
# 99          1  ...       77              7     9.0    both  Regularly busy
#
#       busiest_days busiest_period_of_day    price_range_loc max_order  \
# 0   Regularly days        Average orders  Mid-range product        10
# 1     Slowest days        Average orders  Mid-range product        10
# 2     Slowest days           Most orders  Mid-range product        10
# 3     Slowest days        Average orders  Mid-range product        10
# 4     Slowest days           Most orders  Mid-range product        10
# 5   Regularly days        Average orders  Mid-range product        10
# 6     Busiest days           Most orders  Mid-range product        10
# 7     Busiest days           Most orders  Mid-range product        10
# 8     Busiest days           Most orders  Mid-range product        10
# 9     Slowest days        Average orders  Mid-range product        10
# 10    Busiest days           Most orders  Mid-range product        22
# 11  Regularly days           Most orders  Mid-range product        22
# 12  Regularly days           Most orders  Mid-range product        22
# 13    Busiest days           Most orders  Mid-range product        22
# 14    Busiest days           Most orders  Mid-range product        22
# 15  Regularly days           Most orders  Mid-range product         9
# 16  Regularly days           Most orders  Mid-range product         9
# 17    Slowest days        Average orders  Mid-range product         9
# 18    Slowest days           Most orders  Mid-range product        33
# 19    Slowest days        Average orders  Mid-range product        20
# 20    Slowest days           Most orders  Mid-range product        20
# 21    Slowest days           Most orders  Mid-range product        11
# 22    Slowest days           Most orders  Mid-range product        11
# 23    Busiest days           Most orders  Mid-range product        27
# 24    Busiest days           Most orders  Mid-range product        27
# 25    Busiest days           Most orders  Mid-range product        27
# 26  Regularly days           Most orders  Mid-range product        27
# 27  Regularly days        Average orders  Mid-range product        27
# 28    Busiest days           Most orders  Mid-range product        27
# 29  Regularly days           Most orders  Mid-range product        27
# 30  Regularly days           Most orders  Mid-range product        27
# 31    Busiest days           Most orders  Mid-range product        27
# 32  Regularly days           Most orders  Mid-range product        27
# 33  Regularly days           Most orders  Mid-range product        27
# 34  Regularly days           Most orders  Mid-range product        27
# 35    Slowest days        Average orders  Mid-range product        27
# 36  Regularly days           Most orders  Mid-range product        27
# 37    Slowest days           Most orders  Mid-range product        24
# 38    Busiest days           Most orders  Mid-range product        24
# 39    Busiest days           Most orders  Mid-range product        24
# 40  Regularly days           Most orders  Mid-range product        24
# 41    Slowest days           Most orders  Mid-range product        24
# 42    Slowest days           Most orders  Mid-range product        24
# 43  Regularly days           Most orders  Mid-range product        24
# 44  Regularly days           Most orders  Mid-range product        24
# 45    Busiest days           Most orders  Mid-range product        24
# 46    Busiest days           Most orders  Mid-range product        24
# 47  Regularly days           Most orders  Mid-range product        24
# 48    Busiest days           Most orders  Mid-range product        24
# 49    Busiest days           Most orders  Mid-range product        24
# 50    Slowest days           Most orders  Mid-range product        24
# 51  Regularly days           Most orders  Mid-range product        24
# 52    Busiest days           Most orders  Mid-range product        24
# 53    Busiest days           Most orders  Mid-range product        24
# 54    Busiest days           Most orders  Mid-range product        24
# 55    Busiest days           Most orders  Mid-range product        24
# 56    Busiest days           Most orders  Mid-range product         7
# 57  Regularly days        Average orders  Mid-range product         7
# 58    Slowest days           Most orders  Mid-range product        19
# 59  Regularly days           Most orders  Mid-range product        19
# 60    Busiest days           Most orders  Mid-range product        19
# 61    Slowest days           Most orders  Mid-range product        19
# 62    Busiest days           Most orders  Mid-range product        19
# 63  Regularly days           Most orders  Mid-range product        19
# 64  Regularly days           Most orders  Mid-range product        19
# 65    Busiest days           Most orders  Mid-range product        19
# 66  Regularly days           Most orders  Mid-range product        19
# 67    Busiest days           Most orders  Mid-range product        14
# 68  Regularly days           Most orders  Mid-range product        14
# 69    Slowest days           Most orders  Mid-range product        14
# 70    Slowest days           Most orders  Mid-range product        14
# 71  Regularly days           Most orders  Mid-range product        14
# 72    Slowest days           Most orders  Mid-range product        14
# 73  Regularly days        Average orders  Mid-range product        14
# 74    Slowest days        Average orders  Mid-range product         6
# 75    Slowest days           Most orders  Mid-range product         3
# 76  Regularly days        Average orders  Mid-range product         3
# 77    Busiest days           Most orders  Mid-range product         6
# 78    Busiest days           Most orders  Mid-range product        58
# 79    Busiest days           Most orders  Mid-range product        58
# 80  Regularly days           Most orders  Mid-range product        58
# 81  Regularly days           Most orders  Mid-range product        58
# 82    Busiest days           Most orders  Mid-range product        58
# 83  Regularly days        Average orders  Mid-range product        58
# 84    Slowest days           Most orders  Mid-range product        58
# 85  Regularly days           Most orders  Mid-range product        58
# 86    Slowest days           Most orders  Mid-range product        58
# 87  Regularly days           Most orders  Mid-range product        58
# 88    Slowest days           Most orders  Mid-range product        58
# 89    Slowest days           Most orders  Mid-range product        58
# 90  Regularly days           Most orders  Mid-range product        70
# 91  Regularly days           Most orders  Mid-range product        70
# 92  Regularly days        Average orders  Mid-range product        51
# 93  Regularly days           Most orders  Mid-range product        51
# 94  Regularly days           Most orders  Mid-range product         8
# 95  Regularly days           Most orders  Mid-range product         3
# 96  Regularly days        Average orders  Mid-range product         3
# 97    Slowest days           Most orders  Mid-range product         8
# 98    Busiest days        Average orders  Mid-range product        22
# 99    Slowest days        Average orders  Mid-range product        22
#
#         loyalty_flag
# 0       New customer
# 1       New customer
# 2       New customer
# 3       New customer
# 4       New customer
# 5       New customer
# 6       New customer
# 7       New customer
# 8       New customer
# 9       New customer
# 10  Regular customer
# 11  Regular customer
# 12  Regular customer
# 13  Regular customer
# 14  Regular customer
# 15      New customer
# 16      New customer
# 17      New customer
# 18  Regular customer
# 19  Regular customer
# 20  Regular customer
# 21  Regular customer
# 22  Regular customer
# 23  Regular customer
# 24  Regular customer
# 25  Regular customer
# 26  Regular customer
# 27  Regular customer
# 28  Regular customer
# 29  Regular customer
# 30  Regular customer
# 31  Regular customer
# 32  Regular customer
# 33  Regular customer
# 34  Regular customer
# 35  Regular customer
# 36  Regular customer
# 37  Regular customer
# 38  Regular customer
# 39  Regular customer
# 40  Regular customer
# 41  Regular customer
# 42  Regular customer
# 43  Regular customer
# 44  Regular customer
# 45  Regular customer
# 46  Regular customer
# 47  Regular customer
# 48  Regular customer
# 49  Regular customer
# 50  Regular customer
# 51  Regular customer
# 52  Regular customer
# 53  Regular customer
# 54  Regular customer
# 55  Regular customer
# 56      New customer
# 57      New customer
# 58  Regular customer
# 59  Regular customer
# 60  Regular customer
# 61  Regular customer
# 62  Regular customer
# 63  Regular customer
# 64  Regular customer
# 65  Regular customer
# 66  Regular customer
# 67  Regular customer
# 68  Regular customer
# 69  Regular customer
# 70  Regular customer
# 71  Regular customer
# 72  Regular customer
# 73  Regular customer
# 74      New customer
# 75      New customer
# 76      New customer
# 77      New customer
# 78    Loyal customer
# 79    Loyal customer
# 80    Loyal customer
# 81    Loyal customer
# 82    Loyal customer
# 83    Loyal customer
# 84    Loyal customer
# 85    Loyal customer
# 86    Loyal customer
# 87    Loyal customer
# 88    Loyal customer
# 89    Loyal customer
# 90    Loyal customer
# 91    Loyal customer
# 92    Loyal customer
# 93    Loyal customer
# 94      New customer
# 95      New customer
# 96      New customer
# 97      New customer
# 98  Regular customer
# 99  Regular customer
#
# [100 rows x 21 columns]

# %% [markdown]
# Step 4 : loc() function used in Output 19

# %%
# Checking loyalty flag values
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False).sum()
# Out:
# 32404859

# %%
ords_prods_merge.shape
# Out:
# (32404859, 21)

# %%
# Step 5:
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max','sum']})
# Out:
#                      prices
#                        mean  min      max          sum
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0  106814042.2
# New customer      13.294670  1.0  99999.0   83011787.2
# Regular customer  12.495717  1.0  99999.0  198391693.2

# %% [markdown]
# This is a bit surprising output. The average prices for new customers is highest and loyal customers is lowest. This could be because loyal customers are buying cheaper products. The sum of price paid however is higher for regular customers and loyal customers due to increased number of visits and purchases.

# %%
# Step 6:
ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.loc[ords_prods_merge['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ... prices  _merge     busiest_day    busiest_days  \
# 0          0  ...    9.0    both  Regularly busy  Regularly days
# 1          1  ...    9.0    both  Regularly busy    Slowest days
# 2          1  ...    9.0    both  Regularly busy    Slowest days
# 3          1  ...    9.0    both      Least busy    Slowest days
# 4          1  ...    9.0    both      Least busy    Slowest days
#
#   busiest_period_of_day    price_range_loc max_order  loyalty_flag avg_price  \
# 0        Average orders  Mid-range product        10  New customer  6.367797
# 1        Average orders  Mid-range product        10  New customer  6.367797
# 2           Most orders  Mid-range product        10  New customer  6.367797
# 3        Average orders  Mid-range product        10  New customer  6.367797
# 4           Most orders  Mid-range product        10  New customer  6.367797
#
#    spending_flag
# 0    Low spender
# 1    Low spender
# 2    Low spender
# 3    Low spender
# 4    Low spender
#
# [5 rows x 23 columns]

# %%
#Checking the count of 'spending_flag' values
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False).sum()
# Out:
# 32404859

# %%
ords_prods_merge.shape
# Out:
# (32404859, 23)

# %%
# Step 7:
ords_prods_merge['median_freq'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.loc[ords_prods_merge['median_freq'] > 20, 'order_freq_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_freq'] > 10) & (ords_prods_merge['median_freq'] <= 20), 'order_freq_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_freq'] <= 10, 'order_freq_flag'] = 'Frequent customer'

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            1   2398795        1             2                   3
# 2            2    473747        1             3                   3
# 3            3   2254736        1             4                   4
# 4            4    431534        1             5                   4
# 5            5   3367565        1             6                   2
# 6            6    550135        1             7                   1
# 7            7   3108588        1             8                   1
# 8            8   2295261        1             9                   1
# 9            9   2550362        1            10                   4
# 10         144   2968173       15            15                   1
# 11         146   1870022       15            17                   2
# 12         147   1911383       15            18                   2
# 13         150   2715276       15            21                   1
# 14         151    487368       15            22                   1
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
#
#     reordered  ...     busiest_day    busiest_days  busiest_period_of_day  \
# 0           0  ...  Regularly busy  Regularly days         Average orders
# 1           1  ...  Regularly busy    Slowest days         Average orders
# 2           1  ...  Regularly busy    Slowest days            Most orders
# 3           1  ...      Least busy    Slowest days         Average orders
# 4           1  ...      Least busy    Slowest days            Most orders
# 5           1  ...  Regularly busy  Regularly days         Average orders
# 6           1  ...  Regularly busy    Busiest days            Most orders
# 7           1  ...  Regularly busy    Busiest days            Most orders
# 8           1  ...  Regularly busy    Busiest days            Most orders
# 9           1  ...      Least busy    Slowest days         Average orders
# 10          0  ...  Regularly busy    Busiest days            Most orders
# 11          1  ...  Regularly busy  Regularly days            Most orders
# 12          1  ...  Regularly busy  Regularly days            Most orders
# 13          1  ...  Regularly busy    Busiest days            Most orders
# 14          1  ...  Regularly busy    Busiest days            Most orders
#
#       price_range_loc max_order      loyalty_flag avg_price spending_flag  \
# 0   Mid-range product        10      New customer  6.367797   Low spender
# 1   Mid-range product        10      New customer  6.367797   Low spender
# 2   Mid-range product        10      New customer  6.367797   Low spender
# 3   Mid-range product        10      New customer  6.367797   Low spender
# 4   Mid-range product        10      New customer  6.367797   Low spender
# 5   Mid-range product        10      New customer  6.367797   Low spender
# 6   Mid-range product        10      New customer  6.367797   Low spender
# 7   Mid-range product        10      New customer  6.367797   Low spender
# 8   Mid-range product        10      New customer  6.367797   Low spender
# 9   Mid-range product        10      New customer  6.367797   Low spender
# 10  Mid-range product        22  Regular customer  3.980556   Low spender
# 11  Mid-range product        22  Regular customer  3.980556   Low spender
# 12  Mid-range product        22  Regular customer  3.980556   Low spender
# 13  Mid-range product        22  Regular customer  3.980556   Low spender
# 14  Mid-range product        22  Regular customer  3.980556   Low spender
#
#    median_freq        order_freq_flag
# 0         20.5  Non-frequent customer
# 1         20.5  Non-frequent customer
# 2         20.5  Non-frequent customer
# 3         20.5  Non-frequent customer
# 4         20.5  Non-frequent customer
# 5         20.5  Non-frequent customer
# 6         20.5  Non-frequent customer
# 7         20.5  Non-frequent customer
# 8         20.5  Non-frequent customer
# 9         20.5  Non-frequent customer
# 10        10.0      Frequent customer
# 11        10.0      Frequent customer
# 12        10.0      Frequent customer
# 13        10.0      Frequent customer
# 14        10.0      Frequent customer
#
# [15 rows x 25 columns]

# %%
#Checking the count of 'order_freq_flag' values
ords_prods_merge['order_freq_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_freq_flag, dtype: int64

# %%
ords_prods_merge['order_freq_flag'].value_counts(dropna = False).sum()
# Out:
# 32404859

# %%
# Export the dataframe as a pickle file
ords_prods_merge.to_pickle(r'/Users/shailioza/Documents/CareerFoundry Projects/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged_aggregated.pkl')

# %%
# Further data cleaning steps

ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan
ords_prods_merge['prices'].max()
